# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])
#Shows distribution of unicariate set observations

# %%
sns.distplot(tips['total_bill'],kde=False)

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)

# %%
sns.jointplot(x='total_bill', y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='reg')

# %%
sns.jointplot(data=tips,kind='resid',x='total_bill',y='tip')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
#rugplot
sns.rugplot(tips['total_bill'])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
dataset = np.random.randn(25)

# %%
dataset
# Out:
# array([-0.55567566, -1.27280437, -0.83056932, -1.20581314,  1.55471029,
#        -1.80924631,  0.95153169, -1.11074914, -0.47611208, -0.50799632,
#        -0.39484589, -0.85715429,  0.81481554,  2.04316465, -0.86540821,
#         0.86874967,  0.86261769, -0.0786951 ,  0.87282741,  0.17677709,
#        -0.6661742 ,  0.85656286,  0.9242245 ,  1.11139916, -0.12027456])

# %%
sns.rugplot(dataset)

# %%
x_min = dataset.min() -2
x_max = dataset.max() +2

# %%
x_min, x_max
# Out:
# (-3.809246314395636, 4.0431646540274055)

# %%
x_axis = np.linspace(x_min,x_max,100)

# %%
x_axis
# Out:
# array([-3.80924631e+00, -3.72992903e+00, -3.65061175e+00, -3.57129447e+00,
#        -3.49197718e+00, -3.41265990e+00, -3.33334262e+00, -3.25402534e+00,
#        -3.17470805e+00, -3.09539077e+00, -3.01607349e+00, -2.93675621e+00,
#        -2.85743892e+00, -2.77812164e+00, -2.69880436e+00, -2.61948708e+00,
#        -2.54016979e+00, -2.46085251e+00, -2.38153523e+00, -2.30221795e+00,
#        -2.22290066e+00, -2.14358338e+00, -2.06426610e+00, -1.98494882e+00,
#        -1.90563153e+00, -1.82631425e+00, -1.74699697e+00, -1.66767969e+00,
#        -1.58836240e+00, -1.50904512e+00, -1.42972784e+00, -1.35041056e+00,
#        -1.27109327e+00, -1.19177599e+00, -1.11245871e+00, -1.03314143e+00,
#        -9.53824144e-01, -8.74506862e-01, -7.95189579e-01, -7.15872297e-01,
#        -6.36555014e-01, -5.57237732e-01, -4.77920449e-01, -3.98603166e-01,
#        -3.19285884e-01, -2.39968601e-01, -1.60651319e-01, -8.13340365e-02,
#        -2.01675395e-03,  7.73005286e-02,  1.56617811e-01,  2.35935094e-01,
#         3.15252376e-01,  3.94569659e-01,  4.73886941e-01,  5.53204224e-01,
#         6.32521506e-01,  7.11838789e-01,  7.91156071e-01,  8.70473354e-01,
#         9.49790636e-01,  1.02910792e+00,  1.10842520e+00,  1.18774248e+00,
#         1.26705977e+00,  1.34637705e+00,  1.42569433e+00,  1.50501161e+00,
#         1.58432890e+00,  1.66364618e+00,  1.74296346e+00,  1.82228074e+00,
#         1.90159803e+00,  1.98091531e+00,  2.06023259e+00,  2.13954987e+00,
#         2.21886716e+00,  2.29818444e+00,  2.37750172e+00,  2.45681900e+00,
#         2.53613629e+00,  2.61545357e+00,  2.69477085e+00,  2.77408813e+00,
#         2.85340542e+00,  2.93272270e+00,  3.01203998e+00,  3.09135726e+00,
#         3.17067455e+00,  3.24999183e+00,  3.32930911e+00,  3.40862639e+00,
#         3.48794368e+00,  3.56726096e+00,  3.64657824e+00,  3.72589552e+00,
#         3.80521281e+00,  3.88453009e+00,  3.96384737e+00,  4.04316465e+00])

# %%
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

# %%
bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2

# %%
kernel_list = []

# %%
# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0, 1)
